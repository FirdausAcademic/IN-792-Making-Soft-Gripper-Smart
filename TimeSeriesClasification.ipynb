# %%
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# def readucr_csv(filename):
#     data = pd.read_csv(filename)
#     y = data.iloc[:, 0].values
#     x = data.iloc[:, 1:].values
#     z= data.iloc[:, 2:].values
#     return x, y.astype(int)
def readucr_csv(filename):
    data = pd.read_csv(filename)
    finger1 = data.iloc[:, 0]
    finger2 = data.iloc[:, 1]
    finger3= data.iloc[:, 2]
    return finger1, finger2, finger3

# %%
drive_path = "C:/Users/mdmod/Desktop/Gripper_motor_code/"

finger1, finger2, finger3= readucr_csv(drive_path + "sensor_data_waterbottle1_torq_1.csv")

# %%
print(finger3)
# Out:
# 0       124.0
# 1       122.0
# 2       122.0
# 3       121.0
# 4       123.0
#         ...
# 1995     18.0
# 1996     18.0
# 1997      NaN
# 1998      NaN
# 1999      NaN
# Name: Sensor3, Length: 2000, dtype: float64

# %%
# Plotting column 'A' with Matplotlib
plt.figure(figsize=(10, 6))
plt.plot(finger1.index, finger1, marker='o', linestyle='-', label='Finger1')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of finger1 with Index')
plt.grid(True)
plt.legend()
# plt.show()
plt.figure(figsize=(10, 6))
plt.plot(finger2.index, finger2, marker='o', linestyle='-', label='Finger2')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of finger2 with Index')
plt.grid(True)
plt.legend()
# plt.show()
plt.figure(figsize=(10, 6))
plt.plot(finger3.index, finger3, marker='o', linestyle='-', label='Finger3')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of finger3 with Index')
plt.grid(True)
plt.legend()
plt.show()

# %%
classes = np.unique(np.concatenate((finger1, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()
